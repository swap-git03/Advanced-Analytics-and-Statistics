# %%
2 types of data
Qualitative
Quantitaive
# Out:
#   File "/tmp/ipykernel_3810/2339437993.py", line 1
#     2 types of data
#       ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/content/CDAC_DataBook.xlsx", sheet_name="ERPData")
df.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
x1 = df.MaterialID

# %%
len(np.unique(x1))
# Out:
# 6

# %%
np.unique(x1, return_counts=True)
# Out:
# (array(['AXCP-78', 'DDBN-89', 'GCVB-79', 'LXCV-21', 'SDRT-67', 'TMI-43T'],
#        dtype=object),
#  array([11,  8,  5,  5,  6, 15]))

# %%
x1.value_counts()
# Out:
# MaterialID
# TMI-43T    15
# AXCP-78    11
# DDBN-89     8
# SDRT-67     6
# GCVB-79     5
# LXCV-21     5
# Name: count, dtype: int64

# %%
df1 = x1.value_counts().reset_index()
df1
# Out:
#   MaterialID  count
# 0    TMI-43T     15
# 1    AXCP-78     11
# 2    DDBN-89      8
# 3    SDRT-67      6
# 4    GCVB-79      5
# 5    LXCV-21      5

# %%
df1['prop'] = df1['count']/sum(df1['count'])
df1
# Out:
#   MaterialID  count  prop
# 0    TMI-43T     15  0.30
# 1    AXCP-78     11  0.22
# 2    DDBN-89      8  0.16
# 3    SDRT-67      6  0.12
# 4    GCVB-79      5  0.10
# 5    LXCV-21      5  0.10

# %%
df1['pct']=df1['prop']*100
df1
# Out:
#   MaterialID  count  prop   pct
# 0    TMI-43T     15  0.30  30.0
# 1    AXCP-78     11  0.22  22.0
# 2    DDBN-89      8  0.16  16.0
# 3    SDRT-67      6  0.12  12.0
# 4    GCVB-79      5  0.10  10.0
# 5    LXCV-21      5  0.10  10.0

# %%
x2 = np.array([3,7,5,2,3,8])
np.cumsum(x2)
# Out:
# array([ 3, 10, 15, 17, 20, 28])

# %%
df1['cumpct']=np.cumsum(df1['pct'])
df1
# Out:
#   MaterialID  count  prop   pct  cumpct
# 0    TMI-43T     15  0.30  30.0    30.0
# 1    AXCP-78     11  0.22  22.0    52.0
# 2    DDBN-89      8  0.16  16.0    68.0
# 3    SDRT-67      6  0.12  12.0    80.0
# 4    GCVB-79      5  0.10  10.0    90.0
# 5    LXCV-21      5  0.10  10.0   100.0

# %%
# central teendency = mean, mmedian mode
# dispersion or variation or spread-range interquarttile range, variance and standard deviation
# shape skewnness and kurtoisis

# %% [markdown]
# **day 6**

# %%
df = pd.read_excel("/content/CDAC_DataBook.xlsx", sheet_name="faithful")
df.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
101/2
# Out:
# 50.5

# %%
x1 = df.eruptions

# %%
sum(x1)/len(x1)
# Out:
# 3.487783088235294

# %%
len(x1)
# Out:
# 272

# %%
range, interquearter range, standard deviation

# %%
from scipy import stats

# %%
stats.mode(x1)
# Out:
# ModeResult(mode=np.float64(1.867), count=np.int64(8))

# %%
len(np.where(x1==1.867)[0])
# Out:
# 8

# %%
from collections import Counter

# %%
Counter(x1).most_common
# Out:
# <bound method Counter.most_common of Counter({1.867: 8, 4.5: 8, 1.833: 7, 4.7: 6, 1.75: 6, 4.8: 6, 4.0: 6, 4.533: 5, 4.083: 5, 3.833: 5, 4.333: 5, 3.6: 4, 1.8: 4, 4.35: 4, 4.25: 4, 1.883: 4, 2.0: 4, 4.167: 4, 4.417: 4, 4.6: 4, 4.15: 4, 4.583: 4, 3.917: 3, 1.967: 3, 2.017: 3, 4.567: 3, 2.1: 3, 4.633: 3, 1.817: 3, 1.983: 3, 4.933: 3, 2.2: 3, 4.367: 3, 4.233: 3, 4.45: 3, 3.333: 2, 2.167: 2, 3.85: 2, 4.433: 2, 4.3: 2, 4.467: 2, 4.033: 2, 4.833: 2, 2.233: 2, 4.133: 2, 4.1: 2, 4.067: 2, 3.95: 2, 4.817: 2, 4.667: 2, 4.9: 2, 1.783: 2, 3.767: 2, 1.917: 2, 2.033: 2, 2.4: 2, 3.567: 2, 3.5: 2, 1.933: 2, 2.083: 2, 2.417: 2, 2.25: 2, 4.267: 2, 4.117: 2, 1.85: 2, 4.283: 2, 2.283: 1, 2.883: 1, 1.95: 1, 4.2: 1, 1.6: 1, 3.45: 1, 3.067: 1, 3.367: 1, 4.783: 1, 3.317: 1, 4.716: 1, 1.733: 1, 4.883: 1, 3.717: 1, 1.667: 1, 4.317: 1, 4.4: 1, 2.067: 1, 5.067: 1, 3.883: 1, 2.633: 1, 4.517: 1, 3.75: 1, 2.483: 1, 4.05: 1, 4.85: 1, 3.683: 1, 4.733: 1, 2.3: 1, 1.7: 1, 2.317: 1, 2.617: 1, 2.267: 1, 4.65: 1, 2.8: 1,
# ...

# %%
max(x1) - min(x1)
# Out:
# 3.4999999999999996

# %%
np.ptp(x1)
# Out:
# np.float64(3.4999999999999996)

# %%
iqr = np.percentile(x1,75) - np.percentile(x1,25)
iqr
# Out:
# np.float64(2.2915)

# %%
np.var(x2)
# Out:
# np.float64(4.888888888888888)

# %%
np.std(x2)
# Out:
# np.float64(2.2110831935702664)

# %%
np.var(x2, ddof=1)
# Out:
# np.float64(5.866666666666665)

# %%
np.std(x2, ddof=1)
# Out:
# np.float64(2.422120283277993)

# %%
from scipy.stats import binom

# %%
problem statement

# %%
binom.pmf(10,15,0.7) #for exact output equal to 10 out of 15
# Out:
# np.float64(0.20613038097752098)

# %%
binom.cdf(10,15,0.7) # used for finding out probabilty upto perticular values
# Out:
# np.float64(0.4845089407731571)

# %%
1 - binom.cdf(10,15,0.7) #minimum probability starting from 9 AND further
# Out:
# np.float64(0.5154910592268429)

# %%
from scipy.stats import poisson

# %%
poisson.pmf(12,15)
# Out:
# np.float64(0.08285923436864541)

# %%
poisson.cdf(12,15)
# Out:
# np.float64(0.2676110333925769)

# %%
1 - poisson.cdf(11,15)
# Out:
# np.float64(0.8152482009760685)

# %%
from scipy.stats import norm, t

# %%
norm.cdf(14,16,2.3)
# Out:
# np.float64(0.19226902649831168)

# %%
1 - norm.cdf(14,16,2.3)
# Out:
# np.float64(0.8077309735016883)

# %%
norm.sf(14,16,2.3)
# Out:
# np.float64(0.8077309735016883)

# %% [markdown]
# **Day 7**

# %%
import scipy
from scipy import stats
from scipy.stats import binom, poisson, norm, t

# %%
poisson.pmf(5,7)
# Out:
# np.float64(0.1277166682922895)

# %%
norm.cdf(43,45,2.8)
# Out:
# np.float64(0.2375252620269765)

# %%
z = (43-45)/2.8
z
# Out:
# -0.7142857142857143

# %%
norm.cdf(z, 0,1)
# Out:
# np.float64(0.2375252620269765)

# %%
# Exponential Distrubutions
# Out:
# 43.845

# %%
from scipy.stats import expon

# %%
expon.cdf(100, scale=43.8)
# Out:
# np.float64(0.898032895521957)

# %%
# Out:
# 0.0625

# %%
#prob of event occurs 50 times in 45 days
45*8/30
# Out:
# 12.0

# %%
expon.cdf(8, scale=12)
# Out:
# np.float64(0.486582880967408)
